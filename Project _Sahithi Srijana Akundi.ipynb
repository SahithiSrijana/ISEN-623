# %% [markdown]
# APO Project 2 - Heat exchanger network synthesis - Sahithi Srijana Akundi

# %% [markdown]
# # LP problem

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# %%
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy

# %%
m = gp.Model()
# Out:
# Restricted license - for non-production use only - expires 2023-10-25

# %%
QF = m.addVar(vtype=GRB.CONTINUOUS,name ='QF', lb=0.0)
QHP = m.addVar(vtype=GRB.CONTINUOUS,name ='QHP', lb=0.0, ub = 1000.0)
QLP = m.addVar(vtype=GRB.CONTINUOUS,name ='QLP', lb=0.0, ub = 500)
QCW = m.addVar(vtype=GRB.CONTINUOUS,name ='QCW', lb=0.0)
R1 = m.addVar(vtype=GRB.CONTINUOUS,name ='R1', lb=0.0)
R2 = m.addVar(vtype=GRB.CONTINUOUS,name ='R2', lb=0.0)
R3 = m.addVar(vtype=GRB.CONTINUOUS,name ='R3', lb=0.0)
R4 = m.addVar(vtype=GRB.CONTINUOUS,name ='R4', lb=0.0)
R5 = m.addVar(vtype=GRB.CONTINUOUS,name ='R5', lb=0.0)
R6 = m.addVar(vtype=GRB.CONTINUOUS,name ='R6', lb=0.0)
R7 = m.addVar(vtype=GRB.CONTINUOUS,name ='R7', lb=0.0)
R8 = m.addVar(vtype=GRB.CONTINUOUS,name ='R8', lb=0.0)
R9 = m.addVar(vtype=GRB.CONTINUOUS,name ='R9', lb=0.0)

# %%
m.setObjective(((144)*QF + (86.4)*QHP + (51.84)*QLP + (20.16)*QCW), GRB.MINIMIZE)

# %%
c0 = m.addConstr(QF + 600 == R1 , 'c0')
c1 = m.addConstr(R1+1400 == R2+3500, 'c1')
c2 = m.addConstr(R2+5400 == 4500+R3, 'c2')
c3 = m.addConstr(R3+QHP+3000 == R4+2500, 'c3')
c4 = m.addConstr(R4 + 5200 == R5 + 2000, 'c4')
c5 = m.addConstr(R5+1100 == 2300+R6, 'c5')
c6 = m.addConstr(R6 + QLP+4400 == 9200 + R7, 'c6')
c7 = m.addConstr(R7 + 1100 == R8+1800, 'c7')
c8 = m.addConstr(R8 + 8160 == R9 + 7200, 'c8')
c9 = m.addConstr(R9+2040 == QCW, 'c9')

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 10 rows, 13 columns and 22 nonzeros
# Model fingerprint: 0x44bbb492
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [5e+02, 1e+03]
#   RHS range        [5e+02, 5e+03]
# Presolve removed 10 rows and 13 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7520000e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  4.752000000e+05

# %%
for v in m.getVars():
    print(v.Varname,v.x)
# Out:
# QF 2100.0
# QHP 1000.0
# QLP 500.0
# QCW 3000.0
# R1 2700.0
# R2 600.0
# R3 1500.0
# R4 3000.0
# R5 6200.0
# R6 5000.0
# R7 700.0
# R8 0.0
# R9 960.0

# %% [markdown]
# # MILP Problem

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# %%
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy

# %%
#above pinch


m = gp.Model()


# H = {1,2,3,4,F,H,L}
#C = {1,2,C}

#For sub-networks 'above' and 'below' pinch - and so 4-1 doesnt interact
y11 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y12 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y1c = m.addVar(vtype=GRB.BINARY, lb=0.0)
y21 =m.addVar(vtype=GRB.BINARY, lb=0.0)
y22 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y2c = m.addVar(vtype=GRB.BINARY, lb=0.0)
y31 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y32 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y3c = m.addVar(vtype=GRB.BINARY, lb=0.0)
#y41 = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
y42 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y4c = m.addVar(vtype=GRB.BINARY, lb=0.0)
yf1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yf2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#yfc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
yh1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yh2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#yhc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
yl1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yl2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#ylc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
y = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

r11= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0) 
r12= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r13= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r18= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r23= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r24= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r25= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r35= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r36= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r37= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r38= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r48= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rf1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rh4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rl7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

r1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0) 
r2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q112= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf12= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q113= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q213= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf13= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q114= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q214= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q115= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q215= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q315= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q216= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q226= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q316= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q326= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q217= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q227= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q317= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q327= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

qh27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q228= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q328= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q11 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
              
q21 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q22 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS) 
q31 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q32 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q42 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)
qf1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
qf2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
qh1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
qh2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)   
ql1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS) 
ql2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               


#constraint sum(Qijk) - Qij*yij <=0
m.addConstr(r11 == 600)


m.addConstr(r12-r11 + q112 == 1400)


m.addConstr(r13-r12 + q113  == 1800)
m.addConstr(r23 + q213  == 3600)


m.addConstr(r14-r13 + q114  == 1000)
m.addConstr(r24-r23 + q214  == 2000)


m.addConstr(r15-r14 + q115  == 800)
m.addConstr(r25-r24 + q215  == 1600)
m.addConstr(r35 + q315 == 2800)


m.addConstr(r16-r15   == 0)
m.addConstr(r26-r25 + q216 + q226  == 400)
m.addConstr(r36-r35 + q316 + q326 == 700)


m.addConstr(r17-r16   == 0)
m.addConstr(r27-r26 + q217 + q227  == 1600)
m.addConstr(r37-r36 + q317 + q327 == 2800)


m.addConstr(0-r17  == 0)
m.addConstr(0-r27 + q228  == 400)
m.addConstr(0-r37 + q328 == 700)




#constraint2
m.addConstr(rf1  == 2100)
m.addConstr(rf2-rf1 + qf12 ==0)
m.addConstr(rf3 - rf2 + qf13 == 0)
m.addConstr(rf4 - rf3 + qf14 == 0)
m.addConstr(rh4  + qh14 == 1000)
m.addConstr(rf5 - rf4 + qf15  == 0)
m.addConstr(rh5 - rh4 + qh15  == 0)
m.addConstr(rf6- rf5 + qf16 + qf26  == 0)
m.addConstr(rh6- rh5 + qh16 + qh26  == 0)
m.addConstr(rf7- rf6 + qf17 + qf27  == 0)
m.addConstr(rh7- rh6 + qh17 + qh27  == 0)
m.addConstr(rl7+ ql17 + ql27  == 500)
m.addConstr(0- rf7 + qf28 == 0)
m.addConstr(0- rh7 + qh28 == 0)
m.addConstr(0 - rl7+ ql28  == 0)


#residual across pinch = 0
m.addConstr(rf8+rh8+rl8+r18 + r28 + r38 + r48 ==0)
#constraint3
m.addConstr(q112 + qf12 ==3500)
m.addConstr(q113 + q213 + qf13 == 4500)
m.addConstr(q114 + q214 + qf14 + qh14 == 2500)
m.addConstr(q115 + q215 + q315 + qf15 + qh15 == 2000)
m.addConstr(q216 + q316 + qf16 + qh16 ==500)
m.addConstr(q226 + q326 + qf26 + qh26 == 1800)
m.addConstr(q217 + q317 + qf17 + qh17 + ql17 ==2000)
m.addConstr(q227 + q327 + qf27 + qh27 + ql27 == 7200)
m.addConstr(q228 + q328 + qf28 + qh28 + ql28 ==1800)

#bigM constraint
m.addConstr(q112 + q113 + q114 + q115 <= 300000*y11)
m.addConstr(q213 + q214 + q215 + q216 + q217 <= 300000*y21)
m.addConstr(q226 + q227 + q228  <= 300000*y22)
m.addConstr(q315 + q316 + q317 <= 300000*y31)
m.addConstr(q326 + q327 + q328  <= 300000*y32)
#m.addConstr(y41 ==0)
m.addConstr(qf12 + qf13 + qf14 + qf15 + qf16 + qf17 <= 300000*yf1)
m.addConstr(qf26 + qf27 + qf28  <= 300000*yf2)
m.addConstr(qh14 + qh15 + qh16 + qh17 <= 300000*yh1)
m.addConstr(qh26 + qh27 + qh28  <= 300000*yh2)
m.addConstr(ql17 <= 300000*yl1)
m.addConstr(ql27 + ql28 <= 300000*yl2)


m.addConstr(y == y11 + y21 + y22 + y31 + y32 + yf1 + yf2 + yh1 + yh2 + yl1 + yl2 )
m.addConstr( q112 + q113 + q114 + q115 == q11)
m.addConstr(q213 + q214 + q215 + q216 + q217 == q21)
m.addConstr( q226 + q227 + q228 == q22)
m.addConstr(q315 + q316 + q317 == q31)
m.addConstr(q326 + q327 + q328  == q32)

m.addConstr(qf12 + qf13 + qf14 + qf15 + qf16 + qf17  ==qf1)
m.addConstr(qf26 + qf27 + qf28  == qf2)
m.addConstr(qh14 + qh15 + qh16 + qh17 == qh1)
m.addConstr(qh26 + qh27 + qh28 == qh2)
m.addConstr(ql17 == ql1)
m.addConstr(ql27 + ql28 == ql2)

m.addConstr(rf1 + r11  ==r1)
m.addConstr(rf2 + r12  == r2)
m.addConstr(r13+r23+rf3 == r3)
m.addConstr(r14+r24+rf4+rh4== r4)
m.addConstr(r15+r25+r35+rf5+rh5==r5)
m.addConstr(r16+r26+r36+rf6+rh6==r6)
m.addConstr(r17+r27+r37+rf7+rh7+rl7==r7)

m.setObjective(y11 +y21 + y22 + y31 + y32  + yf1 + yf2 + yh1 + yh2 + yl1 + yl2 , GRB.MINIMIZE)

m.optimize() 

print(f'y11={y11.X}')

print(f'y21={y21.X}')
print(f'y22={y22.X}')
print(f'y31={y31.X}')
print(f'y32={y32.X}')

print(f'yf1={yf1.X}')
print(f'yf2={yf2.X}')
print(f'yh1={yh1.X}')
print(f'yh2={yh2.X}')
print(f'yl1={yl1.X}')
print(f'yl2={yl2.X}')

print(f'q11={q11.X}')

print(f'q21={q21.X}')
print(f'q22={q22.X}')
print(f'q31={q31.X}')
print(f'q32={q32.X}')

print(f'qf1={qf1.X}')
print(f'qf2={qf2.X}')
print(f'qh1={qh1.X}')
print(f'qh2={qh2.X}')
print(f'ql1={ql1.X}')
print(f'ql2={ql2.X}')
print(f'q42={q42.X}')
print(f'r1={r1.X}')
print(f'r2={r2.X}')
print(f'r3={r3.X}')
print(f'r4={r4.X}')
print(f'r5={r5.X}')
print(f'r6={r6.X}')
print(f'r7={r7.X}')
print(f'minimum no of units above pinch={y.X}')
# Out:
# Restricted license - for non-production use only - expires 2023-10-25
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 73 rows, 108 columns and 277 nonzeros
# Model fingerprint: 0x5d030645
# Variable types: 91 continuous, 17 integer (17 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+02, 7e+03]
# Presolve removed 53 rows and 67 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 41 columns, 93 nonzeros
# Variable types: 35 continuous, 6 integer (6 binary)
# Found heuristic solution: objective 7.0000000
#
# Root relaxation: cutoff, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# ...

# %%
#below pinch

m = gp.Model()


# H = {1,2,3,4,F,H,L}
#C = {1,2,C}

#For sub-networks 'above' and 'below' pinch - and so 4-1 doesnt interact
y11 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y12 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y1c = m.addVar(vtype=GRB.BINARY, lb=0.0)
y21 =m.addVar(vtype=GRB.BINARY, lb=0.0)
y22 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y2c = m.addVar(vtype=GRB.BINARY, lb=0.0)
y31 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y32 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y3c = m.addVar(vtype=GRB.BINARY, lb=0.0)
#y41 = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
y42 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y4c = m.addVar(vtype=GRB.BINARY, lb=0.0)
yf1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yf2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#yfc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
yh1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yh2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#yhc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
yl1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yl2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#ylc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
y = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r11= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0) 
r21= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r31= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r41= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r12= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r22= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r32= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r42= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r13= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r23= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r33= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r43= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r24= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r34= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r44= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r25= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r35= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r45= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r36= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r46= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r37= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r47= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r18= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r38= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r48= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r19= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r29= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r39= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r49= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q2c10= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q3c10= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q4c10= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rf1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf9= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rh1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh9= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rl1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl9= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

r9= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q112= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q113= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q213= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q114= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q214= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q115= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q215= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q315= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q216= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q226= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q316= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q326= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q217= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q227= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q317= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q327= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q228= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q328= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q229= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q329= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q429= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf12= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf13= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf29= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh29= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql29= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q11 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q12 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q21 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q22 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS) 
q31 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q32 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q42 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)
qf1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
qf2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
qh1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
qh2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)   
ql1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS) 
ql2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q1c = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q2c = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)
q3c = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q4c = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)


#constraint sum(Qijk) - Qij*yij <=0
m.addConstr(r18==0)
m.addConstr(r28==0)
m.addConstr(r38==0)
m.addConstr(r48==0)
m.addConstr(rf8==0)
m.addConstr(rh8==0)
m.addConstr(rl8==0)

m.addConstr(r19-r18  == 0)
m.addConstr(r29-r28 + q229  == 1600)
m.addConstr(r39-r38 + q329 == 2800)
m.addConstr(r49-r48 + q429 == 3760)

m.addConstr(-r19  == 0)
m.addConstr(-r29 + q2c10  == 400)
m.addConstr(-r39 + q3c10 == 700)
m.addConstr(-r49 + q4c10 == 940)

#constraint2

m.addConstr(rf9- rf8 + qf29 == 0)
m.addConstr(rh9- rh8 + qh29 == 0)
m.addConstr(rl9 - rl8+ ql29  == 0)
m.addConstr(-rf9  == 0)
m.addConstr(-rh9  == 0)
m.addConstr(-rl9  == 0)

#constraint3
m.addConstr(q229 + q329 + q429 + qf29 + qh29 + ql29 == 7200)

#constraint 4
m.addConstr(q2c10 + q3c10 + q4c10 == 3000)

m.addConstr(rf8+rh8+rl8+r18 + r28 + r38 + r48 ==0)
#bigM constraint
m.addConstr(y11==0)
m.addConstr(y12 == 0)
m.addConstr(y21==0)
m.addConstr( q229 <= 300000*y22)
m.addConstr(y31==0)
m.addConstr( q329 <= 300000*y32)
#m.addConstr(y41 ==0)
m.addConstr(q429 <= 300000*y42)
m.addConstr(yf1==0)
m.addConstr(qf29 <= 300000*yf2)
m.addConstr(yh1==0)
m.addConstr(qh29 <= 300000*yh2)
m.addConstr(yl1==0)
m.addConstr( ql29 <= 300000*yl2)
m.addConstr(q2c10 <= 300000*y2c)
m.addConstr(q3c10 <= 300000*y3c)
m.addConstr(q4c10 <= 300000*y4c)
m.addConstr(y == y11 + y12 + y21 + y22 + y31 + y32 + y42 + yf1 + yf2 + yh1 + yh2 + yl1 + yl2 + y1c + y2c + y3c + y4c)

m.setObjective(y11 + y12 + y21 + y22 + y31 + y32 + y42 + yf1 + yf2 + yh1 + yh2 + yl1 + yl2 + y1c + y2c + y3c + y4c, GRB.MINIMIZE)

m.addConstr( q112 + q113 + q114 + q115 == q11)
m.addConstr(q213 + q214 + q215 + q216 + q217 == q21)
m.addConstr(q226 + q227 + q228 + q229 == q22)
m.addConstr(q315 + q316 + q317 == q31)
m.addConstr(q326 + q327 + q328 + q329 == q32)
m.addConstr(q429 == q42)
m.addConstr(qf12 + qf13 + qf14 + qf15 + qf16 + qf17  ==qf1)
m.addConstr(qf26 + qf27 + qf28 + qf29 == qf2)
m.addConstr(qh14 + qh15 + qh16 + qh17 == qh1)
m.addConstr(qh26 + qh27 + qh28 + qh29 == qh2)
m.addConstr(ql17 == ql1)
m.addConstr(ql27 + ql28 + ql29 == ql2)
m.addConstr(q2c10 == q2c)
m.addConstr( q3c10 == q3c)
m.addConstr( q4c10 == q4c)

m.addConstr(r19+r29+r39+r49+rf9+rh9+rl9==r9)

m.optimize() 

print(f'y11={y11.X}')
print(f'y12={y12.X}')
print(f'y21={y21.X}')
print(f'y22={y22.X}')
print(f'y31={y31.X}')
print(f'y32={y32.X}')
print(f'y42={y42.X}')
print(f'yf1={yf1.X}')
print(f'yf2={yf2.X}')
print(f'yh1={yh1.X}')
print(f'yh2={yh2.X}')
print(f'yl1={yl1.X}')
print(f'yl2={yl2.X}')
print(f'y1c={y1c.X}')
print(f'y2c={y2c.X}')
print(f'y3c={y3c.X}')
print(f'y4c={y4c.X}')

print(f'minimum no of units below pinch={y.X}')

print(f'q11={q11.X}')
print(f'q12={q12.X}')
print(f'q21={q21.X}')
print(f'q22={q22.X}')
print(f'q31={q31.X}')
print(f'q32={q32.X}')
print(f'q42={q42.X}')
print(f'qf1={qf1.X}')
print(f'qf2={qf2.X}')
print(f'qh1={qh1.X}')
print(f'qh2={qh2.X}')
print(f'ql1={ql1.X}')
print(f'ql2={ql2.X}')
print(f'q1c={q1c.X}')
print(f'q2c={q2c.X}')
print(f'q3c={q3c.X}')
print(f'q4c={q4c.X}')

print(f'r9={r9.X}')
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 57 rows, 145 columns and 165 nonzeros
# Model fingerprint: 0xb9807f11
# Variable types: 128 continuous, 17 integer (17 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+02, 7e+03]
# Found heuristic solution: objective 7.0000000
# Presolve removed 57 rows and 145 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 6 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# y11=0.0
# y12=0.0
# y21=0.0
# y22=1.0
# y31=0.0
# y32=1.0
# y42=1.0
# yf1=0.0
# yf2=0.0
# yh1=0.0
# ...

# %% [markdown]
# # C1 not allowed to use HP and LP steam

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# %%
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
#yh1, yl1 are forced to zero
import gurobipy as gp
from gurobipy import GRB
import numpy

# %%
#above pinch

m = gp.Model()


# H = {1,2,3,4,F,H,L}
#C = {1,2,C}

#For sub-networks 'above' and 'below' pinch - and so 4-1 doesnt interact
y11 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y12 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y1c = m.addVar(vtype=GRB.BINARY, lb=0.0)
y21 =m.addVar(vtype=GRB.BINARY, lb=0.0)
y22 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y2c = m.addVar(vtype=GRB.BINARY, lb=0.0)
y31 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y32 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y3c = m.addVar(vtype=GRB.BINARY, lb=0.0)
#y41 = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
y42 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y4c = m.addVar(vtype=GRB.BINARY, lb=0.0)
yf1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yf2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#yfc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
yh1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yh2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#yhc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
yl1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yl2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#ylc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
y = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

r11= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0) 
r12= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r13= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r18= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r23= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r24= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r25= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r35= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r36= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r37= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r38= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r48= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rf1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rh4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rl7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

r1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0) 
r2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q112= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf12= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q113= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q213= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf13= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q114= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q214= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q115= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q215= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q315= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q216= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q226= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q316= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q326= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q217= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q227= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q317= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q327= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

qh27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q228= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q328= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q11 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
              
q21 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q22 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS) 
q31 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q32 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q42 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)
qf1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
qf2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
qh1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
qh2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)   
ql1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS) 
ql2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               


#constraint sum(Qijk) - Qij*yij <=0
m.addConstr(r11 == 600)


m.addConstr(r12-r11 + q112 == 1400)


m.addConstr(r13-r12 + q113  == 1800)
m.addConstr(r23 + q213  == 3600)


m.addConstr(r14-r13 + q114  == 1000)
m.addConstr(r24-r23 + q214  == 2000)


m.addConstr(r15-r14 + q115  == 800)
m.addConstr(r25-r24 + q215  == 1600)
m.addConstr(r35 + q315 == 2800)


m.addConstr(r16-r15   == 0)
m.addConstr(r26-r25 + q216 + q226  == 400)
m.addConstr(r36-r35 + q316 + q326 == 700)


m.addConstr(r17-r16   == 0)
m.addConstr(r27-r26 + q217 + q227  == 1600)
m.addConstr(r37-r36 + q317 + q327 == 2800)


m.addConstr(0-r17  == 0)
m.addConstr(0-r27 + q228  == 400)
m.addConstr(0-r37 + q328 == 700)




#constraint2
m.addConstr(rf1  == 2100)
m.addConstr(rf2-rf1 + qf12 ==0)
m.addConstr(rf3 - rf2 + qf13 == 0)
m.addConstr(rf4 - rf3 + qf14 == 0)
m.addConstr(rh4  + qh14 == 1000)
m.addConstr(rf5 - rf4 + qf15  == 0)
m.addConstr(rh5 - rh4 + qh15  == 0)
m.addConstr(rf6- rf5 + qf16 + qf26  == 0)
m.addConstr(rh6- rh5 + qh16 + qh26  == 0)
m.addConstr(rf7- rf6 + qf17 + qf27  == 0)
m.addConstr(rh7- rh6 + qh17 + qh27  == 0)
m.addConstr(rl7+ ql17 + ql27  == 500)
m.addConstr(0- rf7 + qf28 == 0)
m.addConstr(0- rh7 + qh28 == 0)
m.addConstr(0 - rl7+ ql28  == 0)


#residual across pinch = 0
m.addConstr(rf8+rh8+rl8+r18 + r28 + r38 + r48 ==0)
#constraint3
m.addConstr(q112 + qf12 ==3500)
m.addConstr(q113 + q213 + qf13 == 4500)
m.addConstr(q114 + q214 + qf14 + qh14 == 2500)
m.addConstr(q115 + q215 + q315 + qf15 + qh15 == 2000)
m.addConstr(q216 + q316 + qf16 + qh16 ==500)
m.addConstr(q226 + q326 + qf26 + qh26 == 1800)
m.addConstr(q217 + q317 + qf17 + qh17 + ql17 ==2000)
m.addConstr(q227 + q327 + qf27 + qh27 + ql27 == 7200)
m.addConstr(q228 + q328 + qf28 + qh28 + ql28 ==1800)

#bigM constraint
m.addConstr(q112 + q113 + q114 + q115 <= 300000*y11)
m.addConstr(q213 + q214 + q215 + q216 + q217 <= 300000*y21)
m.addConstr(q226 + q227 + q228  <= 300000*y22)
m.addConstr(q315 + q316 + q317 <= 300000*y31)
m.addConstr(q326 + q327 + q328  <= 300000*y32)
#m.addConstr(y41 ==0)
m.addConstr(qf12 + qf13 + qf14 + qf15 + qf16 + qf17 <= 300000*yf1)
m.addConstr(qf26 + qf27 + qf28  <= 300000*yf2)
m.addConstr(qh14 + qh15 + qh16 + qh17 <= 300000*yh1)
m.addConstr(qh26 + qh27 + qh28  <= 300000*yh2)
m.addConstr(ql17 <= 300000*yl1)
m.addConstr(ql27 + ql28 <= 300000*yl2)

m.addConstr(yh1==0)
m.addConstr(yl1==0)

m.addConstr(y == y11 + y21 + y22 + y31 + y32 + yf1 + yf2 + yh1 + yh2 + yl1 + yl2 )
m.addConstr( q112 + q113 + q114 + q115 == q11)
m.addConstr(q213 + q214 + q215 + q216 + q217 == q21)
m.addConstr( q226 + q227 + q228 == q22)
m.addConstr(q315 + q316 + q317 == q31)
m.addConstr(q326 + q327 + q328  == q32)

m.addConstr(qf12 + qf13 + qf14 + qf15 + qf16 + qf17  ==qf1)
m.addConstr(qf26 + qf27 + qf28  == qf2)
m.addConstr(qh14 + qh15 + qh16 + qh17 == qh1)
m.addConstr(qh26 + qh27 + qh28 == qh2)
m.addConstr(ql17 == ql1)
m.addConstr(ql27 + ql28 == ql2)

m.addConstr(rf1 + r11  ==r1)
m.addConstr(rf2 + r12  == r2)
m.addConstr(r13+r23+rf3 == r3)
m.addConstr(r14+r24+rf4+rh4== r4)
m.addConstr(r15+r25+r35+rf5+rh5==r5)
m.addConstr(r16+r26+r36+rf6+rh6==r6)
m.addConstr(r17+r27+r37+rf7+rh7+rl7==r7)

m.setObjective(y11 +y21 + y22 + y31 + y32  + yf1 + yf2 + yh1 + yh2 + yl1 + yl2 , GRB.MINIMIZE)

m.optimize() 

print(f'y11={y11.X}')

print(f'y21={y21.X}')
print(f'y22={y22.X}')
print(f'y31={y31.X}')
print(f'y32={y32.X}')

print(f'yf1={yf1.X}')
print(f'yf2={yf2.X}')
print(f'yh1={yh1.X}')
print(f'yh2={yh2.X}')
print(f'yl1={yl1.X}')
print(f'yl2={yl2.X}')

print(f'q11={q11.X}')

print(f'q21={q21.X}')
print(f'q22={q22.X}')
print(f'q31={q31.X}')
print(f'q32={q32.X}')

print(f'qf1={qf1.X}')
print(f'qf2={qf2.X}')
print(f'qh1={qh1.X}')
print(f'qh2={qh2.X}')
print(f'ql1={ql1.X}')
print(f'ql2={ql2.X}')
print(f'q42={q42.X}')
print(f'r1={r1.X}')
print(f'r2={r2.X}')
print(f'r3={r3.X}')
print(f'r4={r4.X}')
print(f'r5={r5.X}')
print(f'r6={r6.X}')
print(f'r7={r7.X}')
print(f'minimum no of units above pinch={y.X}')
# Out:
# Restricted license - for non-production use only - expires 2023-10-25
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 75 rows, 108 columns and 279 nonzeros
# Model fingerprint: 0xe4f2a28e
# Variable types: 91 continuous, 17 integer (17 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+02, 7e+03]
# Presolve removed 59 rows and 77 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 31 columns, 66 nonzeros
# Variable types: 29 continuous, 2 integer (2 binary)
# Found heuristic solution: objective 7.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7
#
# Optimal solution found (tolerance 1.00e-04)
# ...

# %%
#number of units below pinch is going to be the same as yh1=0 and yl1=0 are already implemented

# %%
#below pinch

m = gp.Model()


# H = {1,2,3,4,F,H,L}
#C = {1,2,C}

#For sub-networks 'above' and 'below' pinch - and so 4-1 doesnt interact
y11 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y12 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y1c = m.addVar(vtype=GRB.BINARY, lb=0.0)
y21 =m.addVar(vtype=GRB.BINARY, lb=0.0)
y22 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y2c = m.addVar(vtype=GRB.BINARY, lb=0.0)
y31 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y32 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y3c = m.addVar(vtype=GRB.BINARY, lb=0.0)
#y41 = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
y42 = m.addVar(vtype=GRB.BINARY, lb=0.0)
y4c = m.addVar(vtype=GRB.BINARY, lb=0.0)
yf1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yf2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#yfc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
yh1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yh2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#yhc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
yl1 = m.addVar(vtype=GRB.BINARY, lb=0.0)
yl2 = m.addVar(vtype=GRB.BINARY, lb=0.0)
#ylc = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
y = m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r11= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0) 
r21= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r31= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r41= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r12= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r22= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r32= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r42= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r13= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r23= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r33= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r43= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r24= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r34= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r44= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r25= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r35= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r45= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r36= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r46= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r37= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r47= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r18= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r38= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r48= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r19= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r29= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r39= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
r49= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q2c10= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q3c10= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q4c10= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rf1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rf9= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rh1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rh9= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

rl1= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl2= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl3= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl4= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl5= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl6= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl7= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl8= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
rl9= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

r9= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q112= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q113= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q213= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q114= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q214= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q115= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q215= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q315= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q216= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q226= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q316= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q326= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q217= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q227= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q317= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q327= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q228= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q328= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q229= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q329= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
q429= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf12= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf13= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh14= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh15= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh16= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh26= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql17= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql27= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql28= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qf29= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
qh29= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)
ql29= m.addVar(vtype=GRB.CONTINUOUS, lb=0.0)

q11 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q12 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q21 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q22 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS) 
q31 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q32 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q42 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)
qf1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
qf2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
qh1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
qh2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)   
ql1 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS) 
ql2 = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)               
q1c = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q2c = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)
q3c = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)              
q4c = m.addVar(lb = 0, vtype=GRB.CONTINUOUS)


#constraint sum(Qijk) - Qij*yij <=0
m.addConstr(r18==0)
m.addConstr(r28==0)
m.addConstr(r38==0)
m.addConstr(r48==0)
m.addConstr(rf8==0)
m.addConstr(rh8==0)
m.addConstr(rl8==0)

m.addConstr(r19-r18  == 0)
m.addConstr(r29-r28 + q229  == 1600)
m.addConstr(r39-r38 + q329 == 2800)
m.addConstr(r49-r48 + q429 == 3760)

m.addConstr(-r19  == 0)
m.addConstr(-r29 + q2c10  == 400)
m.addConstr(-r39 + q3c10 == 700)
m.addConstr(-r49 + q4c10 == 940)

#constraint2

m.addConstr(rf9- rf8 + qf29 == 0)
m.addConstr(rh9- rh8 + qh29 == 0)
m.addConstr(rl9 - rl8+ ql29  == 0)
m.addConstr(-rf9  == 0)
m.addConstr(-rh9  == 0)
m.addConstr(-rl9  == 0)

#constraint3
m.addConstr(q229 + q329 + q429 + qf29 + qh29 + ql29 == 7200)

#constraint 4
m.addConstr(q2c10 + q3c10 + q4c10 == 3000)

m.addConstr(rf8+rh8+rl8+r18 + r28 + r38 + r48 ==0)
#bigM constraint
m.addConstr(y11==0)
m.addConstr(y12 == 0)
m.addConstr(y21==0)
m.addConstr( q229 <= 300000*y22)
m.addConstr(y31==0)
m.addConstr( q329 <= 300000*y32)
#m.addConstr(y41 ==0)
m.addConstr(q429 <= 300000*y42)
m.addConstr(yf1==0)
m.addConstr(qf29 <= 300000*yf2)
m.addConstr(yh1==0)
m.addConstr(qh29 <= 300000*yh2)
m.addConstr(yl1==0)
m.addConstr( ql29 <= 300000*yl2)
m.addConstr(q2c10 <= 300000*y2c)
m.addConstr(q3c10 <= 300000*y3c)
m.addConstr(q4c10 <= 300000*y4c)
m.addConstr(y == y11 + y12 + y21 + y22 + y31 + y32 + y42 + yf1 + yf2 + yh1 + yh2 + yl1 + yl2 + y1c + y2c + y3c + y4c)

m.setObjective(y11 + y12 + y21 + y22 + y31 + y32 + y42 + yf1 + yf2 + yh1 + yh2 + yl1 + yl2 + y1c + y2c + y3c + y4c, GRB.MINIMIZE)

m.addConstr( q112 + q113 + q114 + q115 == q11)
m.addConstr(q213 + q214 + q215 + q216 + q217 == q21)
m.addConstr(q226 + q227 + q228 + q229 == q22)
m.addConstr(q315 + q316 + q317 == q31)
m.addConstr(q326 + q327 + q328 + q329 == q32)
m.addConstr(q429 == q42)
m.addConstr(qf12 + qf13 + qf14 + qf15 + qf16 + qf17  ==qf1)
m.addConstr(qf26 + qf27 + qf28 + qf29 == qf2)
m.addConstr(qh14 + qh15 + qh16 + qh17 == qh1)
m.addConstr(qh26 + qh27 + qh28 + qh29 == qh2)
m.addConstr(ql17 == ql1)
m.addConstr(ql27 + ql28 + ql29 == ql2)
m.addConstr(q2c10 == q2c)
m.addConstr( q3c10 == q3c)
m.addConstr( q4c10 == q4c)

m.addConstr(r19+r29+r39+r49+rf9+rh9+rl9==r9)

m.optimize() 

print(f'y11={y11.X}')
print(f'y12={y12.X}')
print(f'y21={y21.X}')
print(f'y22={y22.X}')
print(f'y31={y31.X}')
print(f'y32={y32.X}')
print(f'y42={y42.X}')
print(f'yf1={yf1.X}')
print(f'yf2={yf2.X}')
print(f'yh1={yh1.X}')
print(f'yh2={yh2.X}')
print(f'yl1={yl1.X}')
print(f'yl2={yl2.X}')
print(f'y1c={y1c.X}')
print(f'y2c={y2c.X}')
print(f'y3c={y3c.X}')
print(f'y4c={y4c.X}')

print(f'minimum no of units below pinch={y.X}')

print(f'q11={q11.X}')
print(f'q12={q12.X}')
print(f'q21={q21.X}')
print(f'q22={q22.X}')
print(f'q31={q31.X}')
print(f'q32={q32.X}')
print(f'q42={q42.X}')
print(f'qf1={qf1.X}')
print(f'qf2={qf2.X}')
print(f'qh1={qh1.X}')
print(f'qh2={qh2.X}')
print(f'ql1={ql1.X}')
print(f'ql2={ql2.X}')
print(f'q1c={q1c.X}')
print(f'q2c={q2c.X}')
print(f'q3c={q3c.X}')
print(f'q4c={q4c.X}')

print(f'r9={r9.X}')
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 57 rows, 145 columns and 165 nonzeros
# Model fingerprint: 0xb9807f11
# Variable types: 128 continuous, 17 integer (17 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e+02, 7e+03]
# Found heuristic solution: objective 7.0000000
# Presolve removed 57 rows and 145 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 2: 6 7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.000000000000e+00, best bound 6.000000000000e+00, gap 0.0000%
# y11=0.0
# y12=0.0
# y21=0.0
# y22=1.0
# y31=0.0
# y32=1.0
# y42=1.0
# yf1=0.0
# yf2=0.0
# yh1=0.0
# ...

# %% [markdown]
# # NLP model

# %% [markdown]
# # above pinch

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# %%
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.core import *
from pyomo.opt import SolverFactory

# %%
m = pyo.ConcreteModel()
import cyipopt

# %%
#above pinch
#variables 
#variables 
m.U = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A11 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A21 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A22 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A32 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A42 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.AF1 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.AH1 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.AL1 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A2C = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A3C = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A4C = pyo.Var(initialize = 1.0, domain=PositiveReals)

#H1 Superstructure variables: Since, there is only H1-C1 combination, no mixers or splitters are present
m.t11in = pyo.Var(initialize = 400.0, domain=NonNegativeReals)
m.t11out = pyo.Var(initialize = 650.0, domain=NonNegativeReals)

#H2 Superstructure variables: H2-C1, H2-C2 combinations are possible
m.F1 = pyo.Var(initialize = 1.0, domain=NonNegativeReals)
m.F2 = pyo.Var(initialize = 1.0, domain=NonNegativeReals)
m.F3 = pyo.Var(initialize = 1.0, domain=NonNegativeReals)
m.F4 = pyo.Var(initialize = 1.0, domain=NonNegativeReals)
m.F5 = pyo.Var(initialize = 1.0, domain=NonNegativeReals)
m.F6 = pyo.Var(initialize = 1.0, domain=NonNegativeReals)
m.F7 = pyo.Var(initialize = 1.0, domain=NonNegativeReals)
m.F8 = pyo.Var(initialize = 1.0, domain=NonNegativeReals)
m.T21in = pyo.Var(initialize = 600.0, domain=NonNegativeReals)
m.T21out = pyo.Var(initialize = 455.0, domain=NonNegativeReals)
m.t21in = pyo.Var(initialize = 422.0, domain=NonNegativeReals)
m.t21out = pyo.Var(initialize = 538.0, domain=NonNegativeReals)
m.T22in = pyo.Var(initialize = 455.0, domain=NonNegativeReals)
m.T22out = pyo.Var(initialize = 360.0, domain=NonNegativeReals)
m.t22in = pyo.Var(initialize = 340.0, domain=NonNegativeReals)
m.t22out = pyo.Var(initialize = 400.0, domain=NonNegativeReals)

#H3 Superstructure variables: H3-C2 combination is possible
m.T32in = pyo.Var(initialize = 460, domain=NonNegativeReals)
m.T32out = pyo.Var(initialize = 360.0, domain=NonNegativeReals)
m.t32in = pyo.Var(initialize = 340.0, domain=NonNegativeReals)
m.t32out = pyo.Var(initialize = 400.0, domain=NonNegativeReals)

#C1 Superstructure variables: H1-C1, H2-C1, F-C1, H-C1, L-C1
m.F9 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F10 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F11 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F12 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F13 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F14 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F15 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F16 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F17 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F18 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F19 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F20 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F21 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F22 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F23 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F24 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F25 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F26 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F27 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F28 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F29 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F30 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F31 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F32 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F33 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F34 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F35 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F36 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F37 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F38 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F39 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F40 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F41 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F42 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F43 = Var(initialize = 1.0, domain=NonNegativeReals)
m.tF1in = pyo.Var(initialize = 380.0, domain=NonNegativeReals)
m.tF1out = pyo.Var(initialize = 422.0, domain=NonNegativeReals)
m.tH1in = pyo.Var(initialize = 360.0, domain=NonNegativeReals)
m.tH1out = pyo.Var(initialize = 380.0, domain=NonNegativeReals)
m.tL1in = pyo.Var(initialize = 350.0, domain=NonNegativeReals)
m.tL1out = pyo.Var(initialize = 360.0, domain=NonNegativeReals)

#C2 Superstructure variable: H2-C2, H3-C2 combinations are possible
m.F44 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F45 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F46 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F47 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F48 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F49 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F50 = Var(initialize = 1.0, domain=NonNegativeReals)
m.F51 = Var(initialize = 1.0, domain=NonNegativeReals)


#mass and energy balance near splitters and mixers
#H1-C1
m.h111 = pyo.Constraint(expr = (700 - m.t11out >= 20))
m.h112 = pyo.Constraint(expr = (420 - m.t11in >= 20))
m.h113 = pyo.Constraint(expr = (5600 == m.A11*(((700-m.t11out)*(420-m.t11in)*\
                                                (700 - m.t11in + 420 - m.t11out)/2)**(1/3))))

#H2-C1, H2-C2
m.h201 = pyo.Constraint(expr = (m.F1 + m.F2 == 40))
m.h202 = pyo.Constraint(expr = (m.F1 + m.F8 == m.F3))
m.h203 = pyo.Constraint(expr = (m.F1*600 + m.F8*m.T22out == m.F3*m.T21in))
m.h204 = pyo.Constraint(expr = (m.F2 + m.F6 == m.F4))
m.h205 = pyo.Constraint(expr = (m.F2*600 + m.F6*m.T21out == m.F4*m.T22in))
m.h206 = pyo.Constraint(expr = (m.F5 + m.F6 == m.F3))
m.h207 = pyo.Constraint(expr = (m.F7 + m.F8 == m.F4))
m.h208 = pyo.Constraint(expr = (m.F5 + m.F7 == 40))
m.h209 = pyo.Constraint(expr = (m.F3*(m.T21in - m.T21out) == 5800))
m.h210 = pyo.Constraint(expr = (m.F4*(m.T22in - m.T22out) == 3800))
m.h211 = pyo.Constraint(expr = (m.T21in - m.t21out >= 20))
m.h212 = pyo.Constraint(expr = (m.T21out - m.t21in  >= 20))
m.h213 = pyo.Constraint(expr = (m.T22in - m.t22out >= 20))
m.h214 = pyo.Constraint(expr = (m.T22out - m.t22in >= 20))
m.h215 = pyo.Constraint(expr = (5800 == m.A21*(((m.T21in - m.t21out )*(m.T21out - m.t21in)*\
                                                (m.T21out - m.t21in + m.T21in - m.t21out)/2)**(1/3))))
m.h216 = pyo.Constraint(expr = (3800 == m.A22*(((m.T22in - m.t22out )*(m.T22out - m.t22in)*\
                                                (m.T22out - m.t22in + m.T22in - m.t22out)/2)**(1/3))))

#H3-C2
m.h311 = pyo.Constraint(expr = (460 - m.t32out >= 20))
m.h312 = pyo.Constraint(expr = (360 - m.t32in >= 20))
m.h313 = pyo.Constraint(expr = (7000 == m.A32*(((460 - m.t32out  )*(360 - m.t32in)*\
                                      (460 - m.t32out + 360 - m.t32in)/2)**(1/3))))

#C1 constraints
m.c101 = pyo.Constraint(expr = (m.F9 + m.F10 + m.F11 + m.F12 + m.F13 == 50))
m.c102 = pyo.Constraint(expr = (m.F9 + m.F25 + m.F30 + m.F35 + m.F40 == m.F14))
m.c103 = pyo.Constraint(expr = (m.F9*350 + m.F25*m.t21out + m.F30*m.tF1out + m.F35*m.tH1out + m.F40*m.tL1out == m.F14*m.t11in))
m.c104 = pyo.Constraint(expr = (m.F10 + m.F20 + m.F31 + m.F36 + m.F41 == m.F15))
m.c105 = pyo.Constraint(expr = (m.F10*350 + m.F20*m.t11out + m.F31*m.tF1out + m.F36*m.tH1out + m.F41*m.tL1out == m.F15*m.t21in))
m.c106 = pyo.Constraint(expr = (m.F11 + m.F21 + m.F26 + m.F37 + m.F42 == m.F16))
m.c107 = pyo.Constraint(expr = (m.F11*350 + m.F21*m.t11out + m.F26*m.t21out + m.F37*m.tH1out + m.F42*m.tL1out == m.F16*m.tF1in))
m.c108 = pyo.Constraint(expr = (m.F12 + m.F22 + m.F27 + m.F32 + m.F43 == m.F17))
m.c109 = pyo.Constraint(expr = (m.F12*350 + m.F22*m.t11out + m.F27*m.t21out + m.F32*m.tF1out + m.F43*m.tL1out == m.F17*m.tH1in))
m.c110 = pyo.Constraint(expr = (m.F13 + m.F23 + m.F28 + m.F33 + m.F38 == m.F18))
m.c111 = pyo.Constraint(expr = (m.F13*350 + m.F23*m.t11out + m.F28*m.t21out + m.F33*m.tF1out + m.F38*m.tH1out == m.F18*m.tL1in))
m.c112 = pyo.Constraint(expr = (m.F19 + m.F20 + m.F21 + m.F22 + m.F23 == m.F14))
m.c113 = pyo.Constraint(expr = (m.F24 + m.F25 + m.F26 + m.F27 + m.F28 == m.F15))
m.c114 = pyo.Constraint(expr = (m.F29 + m.F30 + m.F31 + m.F32 + m.F33 == m.F16))
m.c115 = pyo.Constraint(expr = (m.F34 + m.F35 + m.F36 + m.F37 + m.F38 == m.F17))
m.c116 = pyo.Constraint(expr = (m.F39 + m.F40 + m.F41 + m.F42 + m.F43 == m.F18))
m.c117 = pyo.Constraint(expr = (m.F19 + m.F24 + m.F29 + m.F34 + m.F39 == 50))
m.c118 = pyo.Constraint(expr = (m.F14*(m.t11out - m.t11in) == 5600))
m.c119 = pyo.Constraint(expr = (m.F15*(m.t21out - m.t21in) == 5800))
m.c120 = pyo.Constraint(expr = (m.F16*(m.tF1out - m.tF1in) == 2100))
m.c121 = pyo.Constraint(expr = (m.F17*(m.tH1out - m.tH1in) == 1000))
m.c122 = pyo.Constraint(expr = (m.F18*(m.tL1out - m.tL1in) == 500))
m.c123 = pyo.Constraint(expr = (700 - m.t11out  >= 20))
m.c124 = pyo.Constraint(expr = (420 - m.t11in  >= 20))
#m.c125 = pyo.Constraint(expr = (m.T21in - m.t21out  >= 20))
#m.c126 = pyo.Constraint(expr = (m.T21out - m.t21in  >= 20))
m.c127 = pyo.Constraint(expr = (750 - m.tF1out  >= 20))
m.c128 = pyo.Constraint(expr = (750 - m.tF1in  >= 20))
m.c129 = pyo.Constraint(expr = (510 - m.tH1out  >= 20))
m.c130 = pyo.Constraint(expr = (510 - m.tH1in  >= 20))
m.c131 = pyo.Constraint(expr = (410 - m.tL1out  >= 20))
m.c132 = pyo.Constraint(expr = (410 - m.tL1out >= 20))
m.c133 = pyo.Constraint(expr = (5600 == m.A11*(((700-m.t11out)*(420-m.t11in)*\
                                        (700 - m.t11in  + 420 - m.t11out)/2)**(1/3))))
m.c134 = pyo.Constraint(expr = (5800 == m.A21*(((m.T21in - m.t21out )*(m.T21out - m.t21in)*\
                                        (m.T21out - m.t21in + m.T21in - m.t21out)/2)**(1/3))))
m.c135 = pyo.Constraint(expr = (2100 == m.AF1*(((750 - m.tF1out )*(750 - m.tF1in)*\
                                        (750 - m.tF1in + 750 - m.tF1out)/2)**(1/3))))
m.c136 = pyo.Constraint(expr = (1000 == m.AH1*(((510 - m.tH1out )*(510 - m.tH1in )*\
                                        (510 - m.tH1out + 510 - m.tH1in )/2)**(1/3))))
m.c137 = pyo.Constraint(expr = (500 == m.AL1*(((410 - m.tL1out )*(410 - m.tL1out)*\
                                        (410 - m.tL1out + 410 - m.tL1out)/2)**(1/3))))

#C2 constraints
m.c201 = pyo.Constraint(expr = (m.F44 + m.F45 == 180))
m.c202 = pyo.Constraint(expr = (m.F44 + m.F51 == m.F46))
m.c203 = pyo.Constraint(expr = (m.F44*300 + m.F51*m.t32out == m.F46*m.t22in))
m.c204 = pyo.Constraint(expr = (m.F45 + m.F49 == m.F47))
m.c205 = pyo.Constraint(expr = (m.F45*300 + m.F49*m.t22out == m.F47*m.t32in))
m.c206 = pyo.Constraint(expr = (m.F48 + m.F49 == m.F46))
m.c207 = pyo.Constraint(expr = (m.F50 + m.F51 == m.F47))
m.c208 = pyo.Constraint(expr = (m.F48 + m.F50 == 180))
m.c209 = pyo.Constraint(expr = (m.F46*(m.t22out - m.t22in) == 3800))
m.c210 = pyo.Constraint(expr = (m.F47*(m.t32out - m.t32in) == 7000))
#m.c211 = pyo.Constraint(expr = (m.T22in - m.t22out  >= 20))
#m.c212 = pyo.Constraint(expr = (m.T22out - m.t22in  >= 20))
#m.c213 = pyo.Constraint(expr = (m.T32in - m.t32out  >= 20))
#m.c214 = pyo.Constraint(expr = (m.T32out - m.t32in  >= 20))
m.c217 = pyo.Constraint(expr = (3800 == m.A22*(((m.T22in - m.t22out )*(m.T22out - m.t22in)*\
                                      (m.T22out - m.t22in + m.T22in - m.t22out)/2)**(1/3))))
m.c218 = pyo.Constraint(expr = (7000 == m.A32*(((460 - m.t32out )*(360 - m.t32in)*\
                                      (460 - m.t32in + 360 - m.t32out)/2)**(1/3))))


#Objective Function:
m.obj = pyo.Objective(expr = (4000*(m.A11**0.6 + m.A21**0.6 + m.A22**0.6 + \
                                    m.A32**0.6 + m.AF1**0.6 + \
                                    m.AH1**0.6 + m.AL1**0.6 )), sense=minimize)

solver = pyo.SolverFactory('ipopt')
solver.options['halt_on_ampl_error'] = 'yes'
solver.solve(m,tee=True)

print('Cost of exchangers',value(m.obj))

print('A11=',value(m.A11))
print('A21=',value(m.A21))
print('A22=',value(m.A22))
print('A32=',value(m.A32))
print('AF1=',value(m.AF1))
print('AH1=',value(m.AH1))
print('AL1=',value(m.AL1))
# Out:
# Ipopt 3.11.1: halt_on_ampl_error=yes
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# NOTE: You are using Ipopt by default with the MUMPS linear solver.
#       Other linear solvers might be more efficient (see Ipopt documentation).
#
#
# This is Ipopt version 3.11.1, running with linear solver mumps.
#
# Number of nonzeros in equality constraint Jacobian...:      244
# Number of nonzeros in inequality constraint Jacobian.:       20
# Number of nonzeros in Lagrangian Hessian.............:       99
#
# Total number of variables............................:       76
#                      variables with only lower bounds:       76
# ...

# %% [markdown]
# # NLP below pinch

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# %%
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
import pyomo.environ as pyo
from pyomo.environ import *
from pyomo.core import *
from pyomo.opt import SolverFactory

# %%
m = pyo.ConcreteModel()
import cyipopt

# %%
#variables 
m.U = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A11 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A21 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A22 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A32 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A42 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.AF1 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.AH1 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.AL1 = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A2C = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A3C = pyo.Var(initialize = 1.0, domain=PositiveReals)
m.A4C = pyo.Var(initialize = 1.0, domain=PositiveReals)


#H2 Superstructure variables: H2-C2, H2-CW combinations are possible
m.F52 = pyo.Var(initialize = 10.0, domain=NonNegativeReals)
m.F53 = pyo.Var(initialize = 10.0, domain=NonNegativeReals)
m.F54 = pyo.Var(initialize = 10.0, domain=NonNegativeReals)
m.F55 = pyo.Var(initialize = 10.0, domain=NonNegativeReals)
m.F56 = pyo.Var(initialize = 10.0, domain=NonNegativeReals)
m.F57 = pyo.Var(initialize = 10.0, domain=NonNegativeReals)
m.F58 = pyo.Var(initialize = 10.0, domain=NonNegativeReals)
m.F59 = pyo.Var(initialize = 10.0, domain=NonNegativeReals)
m.T22in = pyo.Var(initialize = 360.0, domain=NonNegativeReals)
m.T22out = pyo.Var(initialize = 320.0, domain=NonNegativeReals)
m.t22in = pyo.Var(initialize = 300.0, domain=NonNegativeReals)
m.t22out = pyo.Var(initialize = 340.0, domain=NonNegativeReals)
m.T2Cin = pyo.Var(initialize = 320.0, domain=NonNegativeReals)
m.T2Cout = pyo.Var(initialize = 310.0, domain=NonNegativeReals)
m.t2Cin = Var(initialize = 290.0, domain=NonNegativeReals)
m.t2Cout = Var(initialize = 290.0, domain=NonNegativeReals)

#H3 Superstructure variables: H3-C2, H3-CW combinations are possible
m.F60 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F61 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F62 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F63 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F64 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F65 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F66 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F67 = Var(initialize = 10.0, domain=NonNegativeReals)
m.T32in = pyo.Var(initialize = 360, domain=NonNegativeReals)
m.T32out = pyo.Var(initialize = 320.0, domain=NonNegativeReals)
m.t32in = pyo.Var(initialize = 300, domain=NonNegativeReals)
m.t32out = pyo.Var(initialize = 340.0, domain=NonNegativeReals)
m.T3Cin = pyo.Var(initialize = 320.0, domain=NonNegativeReals)
m.T3Cout = pyo.Var(initialize = 310, domain=NonNegativeReals)
m.t3Cin = Var(initialize = 290.0, domain=NonNegativeReals)
m.t3Cout = Var(initialize = 290.0, domain=NonNegativeReals)

#H4 Superstructure variables: H4-C2, H4-CW combinations are possible
m.F68 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F69 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F70 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F71 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F72 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F73 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F74 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F75 = Var(initialize = 10.0, domain=NonNegativeReals)
m.T42in = pyo.Var(initialize = 360.0, domain=NonNegativeReals)
m.T42out = pyo.Var(initialize = 330.0, domain=NonNegativeReals)
m.t42in = pyo.Var(initialize = 300.0, domain=NonNegativeReals)
m.t42out = pyo.Var(initialize = 340.0, domain=NonNegativeReals)
m.T4Cin = pyo.Var(initialize = 330.0, domain=NonNegativeReals)
m.T4Cout = pyo.Var(initialize = 310.0, domain=NonNegativeReals)
m.t4Cin = Var(initialize = 290.0, domain=NonNegativeReals)
m.t4Cout = Var(initialize = 290.0, domain=NonNegativeReals)

#C2 Superstructure variable: H2-C2, H3-C2, H4-C2 combinations are possible
m.F76 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F77 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F78 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F79 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F80 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F81 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F82 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F83 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F84 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F85 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F86 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F87 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F88 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F89 = Var(initialize = 10.0, domain=NonNegativeReals)
m.F90 = Var(initialize = 10.0, domain=NonNegativeReals)

#H2-C2, H2-CW
m.h201 = pyo.Constraint(expr=(m.F52 + m.F53 == 40))
m.h202 = pyo.Constraint(expr=(m.F52 + m.F59 == m.F54))
m.h203 = pyo.Constraint(expr=(m.F52*600 + m.F59*m.T2Cout == m.F54*m.T22in))
m.h204 = pyo.Constraint(expr=(m.F53 + m.F57 == m.F55))
m.h205 = pyo.Constraint(expr=(m.F53*600 + m.F57*m.T22out== m.F55*m.T2Cin))
m.h206 = pyo.Constraint(expr=(m.F56 + m.F57 == m.F54))
m.h207 = pyo.Constraint(expr=(m.F58 + m.F59 == m.F55))
m.h208 = pyo.Constraint(expr=(m.F56 + m.F58 == 40))
m.h209 = pyo.Constraint(expr=(m.F54*(m.T22in - m.T22out) == 1600))
m.h210 = pyo.Constraint(expr=(m.F55*(m.T2Cin - m.T2Cout) == 400))
m.h211 = pyo.Constraint(expr=(m.T22in - m.t22out >= 20))
m.h212 = pyo.Constraint(expr=(m.T22out - m.t22in >= 20))
m.h213 = pyo.Constraint(expr=(m.T2Cin - m.t2Cout  >= 20))
m.h214 = pyo.Constraint(expr=(m.T2Cout - m.t2Cin >= 20))
m.h216 = pyo.Constraint(expr=(m.A22*(((m.T22in - m.t22out)*(m.T22out - m.t22in)*\
                                      (m.T22out - m.t22in + m.T22in - m.t22out)/2)**(1/3)) == 1600))
m.h217 = pyo.Constraint(expr=(m.A2C*(((m.T2Cin - m.t2Cout)*(m.T2Cout - m.t2Cin)*\
                                      (m.T2Cout - m.t2Cin + m.T2Cin - m.t2Cout)/2)**(1/3)) == 400))

#H3-C2, H3-CW
m.h301 = pyo.Constraint(expr=(m.F60 + m.F61 == 70))
m.h302 = pyo.Constraint(expr=(m.F60 + m.F67 == m.F62))
m.h303 = pyo.Constraint(expr=(m.F60*360 + m.F67*m.T3Cout == m.F62*m.T32in))
m.h304 = pyo.Constraint(expr=(m.F61 + m.F65 == m.F63))
m.h305 = pyo.Constraint(expr=(m.F61*360 + m.F65*m.T32out == m.F63*m.T3Cin))
m.h306 = pyo.Constraint(expr=(m.F64 + m.F65 == m.F62))
m.h307 = pyo.Constraint(expr=(m.F66 + m.F67 == m.F63))
m.h308 = pyo.Constraint(expr=(m.F62*(m.T32in - m.T32out) == 2800))
m.h309 = pyo.Constraint(expr=(m.F63*(m.T3Cin - m.T3Cout) == 700))
m.h310 = pyo.Constraint(expr=(m.F64 + m.F66 == 70))
m.h311 = pyo.Constraint(expr=(m.T32in - m.t32out >= 20))
m.h312 = pyo.Constraint(expr=(m.T32out - m.t32in >= 20))
m.h313 = pyo.Constraint(expr=(m.T3Cin - m.t3Cout >= 20))
m.h314 = pyo.Constraint(expr=(m.T3Cout - m.t3Cin >= 20))
m.h315 = pyo.Constraint(expr=(m.A32*(((m.T32in - m.t32out  )*(m.T32out - m.t32in)*\
                                      (m.T32in - m.t32out+m.T32out - m.t32in)/2)**(1/3)) == 2800))
m.h316 = pyo.Constraint(expr=(m.A3C*(((m.T3Cin - m.t3Cout)*(m.T3Cout - m.t3Cin)*\
                                      (m.T3Cout - m.t3Cin + m.T3Cin - m.t3Cout)/2)**(1/3)) == 700))

#H4-C2, H4-CW
m.h401 = pyo.Constraint(expr=(m.F68 + m.F69 == 94))
m.h402 = pyo.Constraint(expr=(m.F68 + m.F75 == m.F70))
m.h403 = pyo.Constraint(expr=(m.F68*360 + m.F75*m.T4Cout == m.F70*m.T42in))
m.h404 = pyo.Constraint(expr=(m.F69 + m.F73 == m.F71))
m.h405 = pyo.Constraint(expr=(m.F69*360 + m.F73*m.T42out == m.F71*m.T4Cin))
m.h406 = pyo.Constraint(expr=(m.F72 + m.F73 == m.F70))
m.h407 = pyo.Constraint(expr=(m.F74 + m.F75 == m.F71))
m.h408 = pyo.Constraint(expr=(m.F70*(m.T42in - m.T42out) == 2800))
m.h409 = pyo.Constraint(expr=(m.F71*(m.T4Cin - m.T4Cout) == 1900))
m.h410 = pyo.Constraint(expr=(m.F72 + m.F74 == 94))
m.h411 = pyo.Constraint(expr=(m.T42in - m.t42out >= 20))
m.h412 = pyo.Constraint(expr=(m.T42out - m.t42in >= 20))
m.h413 = pyo.Constraint(expr=(m.T4Cin - m.t4Cout >= 20))
m.h414 = pyo.Constraint(expr=(m.T4Cout - m.t4Cin >= 20))
m.h415 = pyo.Constraint(expr=(m.A42*(((m.T42in - m.t42out  )*(m.T42out - m.t42in)*\
                                      (m.T42in - m.t42out+m.T42out - m.t42in)/2)**(1/3)) == 2800))
m.h416 = pyo.Constraint(expr=(m.A4C*(((m.T4Cin - m.t4Cout)*(m.T4Cout - m.t4Cin)*\
                                      (m.T4Cout - m.t4Cin + m.T4Cin - m.t4Cout)/2)**(1/3)) == 1900))
#C2 constraints
m.c201 = pyo.Constraint(expr=(m.F76 + m.F77 + m.F78 == 180))
m.c202 = pyo.Constraint(expr=(m.F76 + m.F86 + m.F89 == m.F79))
m.c203 = pyo.Constraint(expr=(m.F76*300 + m.F86*m.t32out + m.F89*m.t42out == m.F79*m.t22in))
m.c204 = pyo.Constraint(expr=(m.F77 + m.F83 + m.F90 == m.F80))
m.c205 = pyo.Constraint(expr=(m.F77*300 + m.F83*m.t22out + m.F90*m.t42out == m.F80*m.t32in))
m.c206 = pyo.Constraint(expr=(m.F78 + m.F84 + m.F87 == m.F81))
m.c207 = pyo.Constraint(expr=(m.F78*300 + m.F84*m.t22out + m.F87*m.t32out == m.F81*m.t42in))
m.c208 = pyo.Constraint(expr=(m.F82 + m.F83 + m.F84 == m.F79))
m.c209 = pyo.Constraint(expr=(m.F85 + m.F86 + m.F87 == m.F80))
m.c210 = pyo.Constraint(expr=(m.F88 + m.F89 + m.F90 == m.F81))
m.c211 = pyo.Constraint(expr=(m.F82 + m.F85 + m.F88 == 180))
m.c212 = pyo.Constraint(expr=(m.F79*(m.t22out - m.t22in) == 1600))
m.c213 = pyo.Constraint(expr=(m.F80*(m.t32out - m.t32in) == 2800))
m.c214 = pyo.Constraint(expr=(m.F81*(m.t42out - m.t42in) == 2800))
m.c215 = pyo.Constraint(expr=(m.T22in - m.t22out  >= 20))
m.c216 = pyo.Constraint(expr=(m.T22out - m.t22in  >= 20))
m.c217 = pyo.Constraint(expr=(m.T32in - m.t32out  >= 20))
m.c218 = pyo.Constraint(expr=(m.T32out - m.t32in  >= 20))
m.c219 = pyo.Constraint(expr=(m.T42in - m.t42out  >= 20))
m.c220 = pyo.Constraint(expr=(m.T42out - m.t42in  >= 20))
m.c221 = pyo.Constraint(expr=(m.A22*(((m.T22in - m.t22out )*(m.T22out - m.t22in)*\
                                      (m.T22out - m.t22in + m.T22in - m.t22out)/2)**(1/3)) == 1600))
m.c222 = pyo.Constraint(expr=(m.A32*(((m.T32in - m.t32out )*(m.T32out - m.t32in)*\
                                      (m.T32out - m.t32in+m.T32in - m.t32out)/2)**(1/3)) == 2800))
m.c223 = pyo.Constraint(expr=(m.A42*(((m.T42in - m.t42out )*(m.T42out - m.t42in)*\
                                      (m.T42out - m.t42in+m.T42in - m.t42out)/2)**(1/3)) == 2800))

m.obj = pyo.Objective(expr = (4000*(m.A22**0.6 + m.A2C**0.6 +\
                                    m.A32**0.6 + m.A3C**0.6 + \
                                    m.A42**0.6 + m.A4C**0.6)), sense=minimize)

solver = pyo.SolverFactory('ipopt')
solver.options['halt_on_ampl_error'] = 'yes'
solver.solve(m,tee=True)

print('Cost of exchangers =',value(m.obj))

print('A22=',value(m.A22))
print('A2C=',value(m.A2C))
print('A32=',value(m.A32))
print('A3C=',value(m.A3C))
print('A42=',value(m.A42))
print('A4C=',value(m.A4C))
# Out:
# Ipopt 3.11.1: halt_on_ampl_error=yes
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# NOTE: You are using Ipopt by default with the MUMPS linear solver.
#       Other linear solvers might be more efficient (see Ipopt documentation).
#
#
# This is Ipopt version 3.11.1, running with linear solver mumps.
#
# Number of nonzeros in equality constraint Jacobian...:      201
# Number of nonzeros in inequality constraint Jacobian.:       36
# Number of nonzeros in Lagrangian Hessian.............:      120
#
# Total number of variables............................:       69
#                      variables with only lower bounds:       69
# ...
